# %%
import modal
import pandas as pd
import evaluate


# load my modal function from deployment to do inference

def run_inference(d):
    # From Modal, get inference of datapoint d and return

    # grabs function from Modal to run my large language model
    extract = modal.Function.lookup("pkmn-dmg", "run_inference")
    # call run_inference remotely on modal
    result = extract.remote(d)
    return result

# %%
rouge = evaluate.load("rouge")

# %%
# import my evaluation jsonl file so we can run inference on it 


# import evaluation jsonl speed_training_data_eval.jsonl

import jsonlines


eval_set = []
f = "train_action_eval_data.jsonl"
with jsonlines.open(f) as reader:
        for entry in reader:
            eval_set.append(entry)

# %%
eval_set = pd.DataFrame(eval_set).sample(25, random_state=42).reset_index(drop=True)

# %%
eval_set
# Out:
#                                                prompt  \
# 0   Train Foongus using double-slap to ohko Blisse...
# 1   /train Dugtrio using mega-punch to 2hko Kilowa...
# 2   Train Impidimp with tera ice using comet-punch...
# 3   /train Steenee using scratch to 2hko Phantump ...
# 4   /train relaxed Cacturne with choice specs and ...
# 5   Train Gible with choice specs and adamant tera...
# 6   What are the optimal evs for Tsareena to 2hko ...
# 7   Train Altaria with av using thunder-punch to 1...
# 8   Calculate the optimal evs Muk using karate-cho...
# 9   Train Coalossal with banded using ice-punch to...
# 10  Train Tropius using pay-day to 2hko Bombirdier...
# 11  What are the optimal evs for Eelektross to 1hk...
# 12  What are the optimal evs for Oricorio Baile to...
# 13  /train Indeedee Male using double-slap to ohko...
# 14  /train Cufant using ice-punch to 2hko Kricketo...
# 15  /train Klefki using thunder-punch to 2hko Lech...
# 16  /train Eelektrik with choice specs using mega-...
# 17  Calculate the optimal evs for Espathra to 1hko...
# 18  Train Applin using pound to 1hko Sliggoo with ...
# 19  /train Toxtricity Amped with bold nature using...
# 20  /train Brambleghast with av using double-slap ...
# 21  Train Grumpig using thunder-punch to 1hko Garg...
# 22  Train Riolu with tera psychic using pay-day to...
# 23  /train Slaking using fire-punch to ohko Gabite...
# 24  What are the optimal evs for Regieleki to ohko...
#
#                                                output
# 0   \n    {\n        "p1": {"name":"Foongus"},\n  ...
# 1   \n    {\n        "p1": {"name":"Dugtrio"},\n  ...
# 2   \n    {\n        "p1": {"name":"Impidimp", "te...
# 3   \n    {\n        "p1": {"name":"Steenee"},\n  ...
# 4   \n    {\n        "p1": {"name":"Cacturne", "it...
# 5   \n    {\n        "p1": {"name":"Gible", "item"...
# 6   \n    {\n        "p1": {"name":"Tsareena"},\n ...
# 7   \n    {\n        "p1": {"name":"Altaria", "ite...
# 8   \n    {\n        "p1": {"name":"Muk"},\n      ...
# 9   \n    {\n        "p1": {"name":"Coalossal", "i...
# 10  \n    {\n        "p1": {"name":"Tropius"},\n  ...
# 11  \n    {\n        "p1": {"name":"Eelektross"},\...
# 12  \n    {\n        "p1": {"name":"Oricorio Baile...
# 13  \n    {\n        \n        "p1": {"name":"Inde...
# 14  \n    {  \n        "p1": {"name":"Cufant"},\n ...
# 15  \n    {\n        "p1": {"name":"Klefki"},\n   ...
# 16  \n    {\n        "p1": {"name":"Eelektrik", "i...
# 17  \n    {\n        "p1": {"name":"Espathra"},\n ...
# 18  \n    {\n        \n        "p1": {"name":"Appl...
# 19  \n    {\n        \n        "p1": {"name":"Toxt...
# 20  \n    {\n        "p1": {"name":"Brambleghast",...
# 21  \n    {\n        "p1": {"name":"Grumpig"},\n  ...
# 22  \n    {\n        "p1": {"name":"Riolu", "tera_...
# 23  \n    {\n        "p1": {"name":"Slaking"},\n  ...
# 24  \n    {\n        "p1": {"name":"Regieleki"},\n...

# %%
# now run inference on dataframe eval set, and store result in new column


eval_set["inference"] = eval_set["prompt"].apply(run_inference)

# %%
eval_set
# Out:
#                                                prompt  \
# 0   Train Foongus using double-slap to ohko Blisse...
# 1   /train Dugtrio using mega-punch to 2hko Kilowa...
# 2   Train Impidimp with tera ice using comet-punch...
# 3   /train Steenee using scratch to 2hko Phantump ...
# 4   /train relaxed Cacturne with choice specs and ...
# 5   Train Gible with choice specs and adamant tera...
# 6   What are the optimal evs for Tsareena to 2hko ...
# 7   Train Altaria with av using thunder-punch to 1...
# 8   Calculate the optimal evs Muk using karate-cho...
# 9   Train Coalossal with banded using ice-punch to...
# 10  Train Tropius using pay-day to 2hko Bombirdier...
# 11  What are the optimal evs for Eelektross to 1hk...
# 12  What are the optimal evs for Oricorio Baile to...
# 13  /train Indeedee Male using double-slap to ohko...
# 14  /train Cufant using ice-punch to 2hko Kricketo...
# 15  /train Klefki using thunder-punch to 2hko Lech...
# 16  /train Eelektrik with choice specs using mega-...
# 17  Calculate the optimal evs for Espathra to 1hko...
# 18  Train Applin using pound to 1hko Sliggoo with ...
# 19  /train Toxtricity Amped with bold nature using...
# 20  /train Brambleghast with av using double-slap ...
# 21  Train Grumpig using thunder-punch to 1hko Garg...
# 22  Train Riolu with tera psychic using pay-day to...
# 23  /train Slaking using fire-punch to ohko Gabite...
# 24  What are the optimal evs for Regieleki to ohko...
#
#                                                output  \
# 0   \n    {\n        "p1": {"name":"Foongus"},\n  ...
# 1   \n    {\n        "p1": {"name":"Dugtrio"},\n  ...
# 2   \n    {\n        "p1": {"name":"Impidimp", "te...
# 3   \n    {\n        "p1": {"name":"Steenee"},\n  ...
# 4   \n    {\n        "p1": {"name":"Cacturne", "it...
# 5   \n    {\n        "p1": {"name":"Gible", "item"...
# 6   \n    {\n        "p1": {"name":"Tsareena"},\n ...
# 7   \n    {\n        "p1": {"name":"Altaria", "ite...
# 8   \n    {\n        "p1": {"name":"Muk"},\n      ...
# 9   \n    {\n        "p1": {"name":"Coalossal", "i...
# 10  \n    {\n        "p1": {"name":"Tropius"},\n  ...
# 11  \n    {\n        "p1": {"name":"Eelektross"},\...
# 12  \n    {\n        "p1": {"name":"Oricorio Baile...
# 13  \n    {\n        \n        "p1": {"name":"Inde...
# 14  \n    {  \n        "p1": {"name":"Cufant"},\n ...
# 15  \n    {\n        "p1": {"name":"Klefki"},\n   ...
# 16  \n    {\n        "p1": {"name":"Eelektrik", "i...
# 17  \n    {\n        "p1": {"name":"Espathra"},\n ...
# 18  \n    {\n        \n        "p1": {"name":"Appl...
# 19  \n    {\n        \n        "p1": {"name":"Toxt...
# 20  \n    {\n        "p1": {"name":"Brambleghast",...
# 21  \n    {\n        "p1": {"name":"Grumpig"},\n  ...
# 22  \n    {\n        "p1": {"name":"Riolu", "tera_...
# 23  \n    {\n        "p1": {"name":"Slaking"},\n  ...
# 24  \n    {\n        "p1": {"name":"Regieleki"},\n...
#
#                                             inference
# 0       {\n        "p1": {"name":"Foongus"},\n    ...
# 1       {\n        "p1": {"name":"Dugtrio"},\n    ...
# 2       {\n        "p1": {"name":"Impidimp", "tera...
# 3       {\n        "p1": {"name":"Steenee"},\n    ...
# 4       {\n        "p1": {"name":"Cacturne", "item...
# 5       {\n        "p1": {"name":"Gible", "item": ...
# 6       {\n        "p1": {"name":"Tsareena"},\n   ...
# 7       {\n        "p1": {"name":"Altaria", "item"...
# 8       {\n        "p1": {"name":"Muk"},\n        ...
# 9       {\n        "p1": {"name":"Coalossal", "ite...
# 10      {\n        "p1": {"name":"Tropius"},\n    ...
# 11      {\n        "p1": {"name":"Eelektross"},\n ...
# 12      {\n        "p1": {"name":"Oricorio Baile"}...
# 13      {\n        "p1": {"name":"Indeedee Male"},...
# 14      {\n        "p1": {"name":"Cufant"},\n     ...
# 15      {\n        "p1": {"name":"Klefki"},\n     ...
# 16      {\n        "p1": {"name":"Eelektrik", "ite...
# 17      {\n        "p1": {"name":"Espathra"},\n   ...
# 18      {\n        "p1": {"name":"Applin"},\n     ...
# 19      {\n        "p1": {"name":"Toxtricity Amped...
# 20      {\n        "p1": {"name":"Brambleghast", "...
# 21      {\n        "p1": {"name":"Grumpig"},\n    ...
# 22      {\n        "p1": {"name":"Riolu", "tera_ty...
# 23      {\n        "p1": {"name":"Slaking"},\n    ...
# 24      {\n        "p1": {"name":"Regieleki"},\n  ...

# %%
# compute rouge score row by row using inference columna and output column

score_result = rouge.compute(predictions = eval_set["inference"], references = eval_set["output"])


# compute the mean, median, rouge score for the eval set

# pretty print both scores
score_result
# Out:
# {'rouge1': 0.9534938159936435,
#  'rouge2': 0.9292019179736194,
#  'rougeL': 0.9487873934684061,
#  'rougeLsum': 0.9497035078201734}

# %%
score_result = rouge.compute(predictions = eval_set["prompt"], references = eval_set["output"])

# %%
score_result
# Out:
# {'rouge1': 0.5764017822634941,
#  'rouge2': 0.10216799110791516,
#  'rougeL': 0.3424740217997284,
#  'rougeLsum': 0.4645146040180902}
